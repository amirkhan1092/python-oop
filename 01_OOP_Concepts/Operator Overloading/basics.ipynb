# %%
# Operator Overloading

'+'
a = ["12", 34, 43]
b = ["34", 4, 67]
c = a + b
print(c)
# Out:
# ['12', 34, 43, '34', 4, 67]

# %%
class Sample1:
    def __add__(self, other):
        return 'this is + operation'

# main 
obj1 = Sample1()
obj2 = Sample1()
c = obj1
print(c)
# Out:
# this is + operation

# %%
a = 23
b = 34
c = a + b
print(c, type(c))
# Out:
# 57 <class 'int'>

# %%
class CustomNumber:
    def __init__(self, value):
        self.value = value
    def __add__(self, other):
        if isinstance(other, CustomNumber):
            return CustomNumber(self.value + other.value)
        else:
            return CustomNumber(self.value + other)
    def __str__(self):
        return f'{self.value}'
# main
a = CustomNumber(12)
b = CustomNumber(2)
c =  a + 34
print(c, type(c))
# Out:
# 32 <class 'int'>

# %%
a = 2 + 3j

print(isinstance(a, complex) )
# Out:
# True

# %%
# Operator Overloading in Python
class CustomNumber:
    def __init__(self, value):
        self.value = value

    def method1(self, other):
        print('Hi', self.value, other.value)
    
    def __add__(self, other):
        return None

    


a = CustomNumber(12)
b = CustomNumber(34)

c = a + b
print(c)
# Out:
# None
