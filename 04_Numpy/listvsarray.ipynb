# %%
import numpy as np
import time

# %%
data = range(1, 10000001)
lst = list(data)
arr = np.array(lst)

# %%
# operations 
strt = time.time()
lst2 = [i*2 for i in lst]
stp = time.time()
duration = stp - strt
print('List Time:', duration)

strt = time.time()
arr2 = arr*2
stp = time.time()
duration = stp - strt
print('Array Time:', duration)
# Out:
# List Time: 0.34267187118530273
# Array Time: 0.011816978454589844
