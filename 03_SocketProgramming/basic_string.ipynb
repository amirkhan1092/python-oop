# %%
data = 'I ❤️ GLA'

val = data.encode('ascii')
print(val)
# Out:
# b'I \xe2\x9d\xa4\xef\xb8\x8f GLA'

# %%
data = b'I \xe2\x9d\xa4\xef\xb8\x8f GLA'

print(data.decode('ascii', errors='replace'))
# Out:
# I ������ GLA

# %%
data = b'hello world'
print(data[0])
# Out:
# 104
